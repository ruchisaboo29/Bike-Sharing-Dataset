# %% [markdown]
# ### Bike Sharing Dataset
#
# https://www.pluralsight.com/guides/regression-keras

# %% [markdown]
# Data Repo link: <href> https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset# </href>

# %% [markdown]
# Data Set Information:
#
# Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return back has become automatic. Through these systems, user is able to easily rent a bike from a particular position and return back at another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic, environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by these systems make them attractive for the research. Opposed to other transport services such as bus or subway, the duration of travel, departure and arrival position is explicitly recorded in these systems. This feature turns bike sharing system into a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of important events in the city could be detected via monitoring these data.
#
#
# Attribute Information:
#
# Both hour.csv and day.csv have the following fields, except hr which is not available in day.csv
#
# - instant: record index
# - dteday : date
# - season : season (1:winter, 2:spring, 3:summer, 4:fall)
# - yr : year (0: 2011, 1:2012)
# - mnth : month ( 1 to 12)
# - hr : hour (0 to 23)
# - holiday : weather day is holiday or not (extracted from [Web Link])
# - weekday : day of the week
# - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# + weathersit :
# - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp : Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39 (only in hourly scale)
# - atemp: Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)
# - hum: Normalized humidity. The values are divided to 100 (max)
# - windspeed: Normalized wind speed. The values are divided to 67 (max)
# - casual: count of casual users
# - registered: count of registered users
# - cnt: count of total rental bikes including both casual and registered

# %%
import pandas as pd
import numpy as np

import tensorflow as tf

import sklearn
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv("/home/ruchisaboo/Downloads/Bike-Sharing-Dataset/hour.csv")

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.shape
# Out:
# (17379, 17)

# %%
df=df.iloc[:,1:]
df.shape
# Out:
# (17379, 16)

# %%
#converting to datetime object and extract days information from dteday column
df['dteday'] = pd.to_datetime(df['dteday'])
df['day'] = pd.DatetimeIndex(df['dteday']).day
df.drop(['dteday'], axis=1, inplace=True)

# %%
#Checking null values
df.isnull().sum()
# Out:
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# day           0
# dtype: int64

# %%
#checking datatype
df.dtypes
# Out:
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# day             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt', 'day'],
#       dtype='object')

# %%
category_features = ['season', 'holiday', 'mnth', 'hr', 'weekday', 'workingday', 'weathersit']
number_features = ['temp', 'atemp', 'hum', 'windspeed']

# %% [markdown]
# converting categorical column to dummy variables

# %%
df1=pd.get_dummies(df['season'],drop_first=True,prefix='season')
df2=pd.get_dummies(df['holiday'],drop_first=True,prefix='holiday')
df3=pd.get_dummies(df['workingday'],drop_first=True,prefix='workingday')
df4=pd.get_dummies(df['weathersit'],drop_first=True,prefix='weathersit')

# %%
df.drop(['season','holiday','workingday','weathersit'],axis=1,inplace=True)
df=pd.concat([df,df1,df2,df3,df4],axis=1)
df.head()
# Out:
#    yr  mnth  hr  weekday  temp   atemp   hum  windspeed  casual  registered  \
# 0   0     1   0        6  0.24  0.2879  0.81        0.0       3          13
# 1   0     1   1        6  0.22  0.2727  0.80        0.0       8          32
# 2   0     1   2        6  0.22  0.2727  0.80        0.0       5          27
# 3   0     1   3        6  0.24  0.2879  0.75        0.0       3          10
# 4   0     1   4        6  0.24  0.2879  0.75        0.0       0           1
#
#    cnt  day  season_2  season_3  season_4  holiday_1  workingday_1  \
# 0   16    1         0         0         0          0             0
# 1   40    1         0         0         0          0             0
# 2   32    1         0         0         0          0             0
# 3   13    1         0         0         0          0             0
# 4    1    1         0         0         0          0             0
#
#    weathersit_2  weathersit_3  weathersit_4
# 0             0             0             0
# 1             0             0             0
# 2             0             0             0
# 3             0             0             0
# 4             0             0             0

# %%
#Doing train test split
train=df.iloc[:14000]
test=df.iloc[14000:]

# %%
train_x, test_x = train.drop(['cnt'],axis=1), test.drop(['cnt'],axis=1)
train_y, test_y = train['cnt'], test['cnt']

# %%
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((14000, 19), (3379, 19), (14000,), (3379,))

# %% [markdown]
# ### Define model

# %%
model1 = tf.keras.models.Sequential([
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(512,input_dim=19, activation=tf.nn.relu),
tf.keras.layers.Dropout(0.2), 
tf.keras.layers.Dense(1)
])

# %%
optimiser = tf.keras.optimizers.Adam()
model1.compile (optimizer= optimiser, loss='mean_squared_error', metrics = ['mean_squared_error'])

# %%
model1.fit(train_x, train_y, epochs=20)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Layer flatten_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 438/438 [==============================] - 0s 699us/step - loss: 1881.4431 - mean_squared_error: 1881.4431
# Epoch 2/20
# 438/438 [==============================] - 0s 699us/step - loss: 127.2408 - mean_squared_error: 127.2408
# Epoch 3/20
# 438/438 [==============================] - 0s 702us/step - loss: 110.8795 - mean_squared_error: 110.8795
# Epoch 4/20
# 438/438 [==============================] - 0s 805us/step - loss: 93.4475 - mean_squared_error: 93.4475
# Epoch 5/20
# 438/438 [==============================] - 0s 773us/step - loss: 87.7107 - mean_squared_error: 87.7107
# Epoch 6/20
# 438/438 [==============================] - 0s 803us/step - loss: 80.1180 - mean_squared_error: 80.1180
# Epoch 7/20
# 438/438 [==============================] - 0s 762us/step - loss: 78.2882 - mean_squared_error: 78.2882
# Epoch 8/20
# 438/438 [==============================] - 0s 772us/step - loss: 74.2651 - mean_squared_error: 74.2651
# Epoch 9/20
# 438/438 [==============================] - 0s 800us/step - loss: 69.7811 - mean_squared_error: 69.7811
# Epoch 10/20
# 438/438 [==============================] - 0s 755us/step - loss: 71.9588 - mean_squared_error: 71.9588
# Epoch 11/20
# 438/438 [==============================] - 0s 763us/step - loss: 72.9725 - mean_squared_error: 72.9725
# Epoch 12/20
# 438/438 [==============================] - 0s 797us/step - loss: 71.7528 - mean_squared_error: 71.7528
# Epoch 13/20
# 438/438 [==============================] - 0s 716us/step - loss: 69.1372 - mean_squared_error: 69.1372
# Epoch 14/20
# 438/438 [==============================] - 0s 823us/step - loss: 74.1924 - mean_squared_error: 74.1924
# Epoch 15/20
# 438/438 [==============================] - 0s 755us/step - loss: 67.2936 - mean_squared_error: 67.2936
# Epoch 16/20
# 438/438 [==============================] - 0s 796us/step - loss: 63.0710 - mean_squared_error: 63.0710
# Epoch 17/20
# 438/438 [==============================] - 0s 780us/step - loss: 64.8378 - mean_squared_error: 64.8378
# Epoch 18/20
# 438/438 [==============================] - 0s 803us/step - loss: 66.0517 - mean_squared_error: 66.0517
# Epoch 19/20
# 438/438 [==============================] - 0s 794us/step - loss: 67.0607 - mean_squared_error: 67.0607
# Epoch 20/20
# 438/438 [==============================] - 0s 814us/step - loss: 62.8980 - mean_squared_error: 62.8980

# %% [markdown]
# ### Predict on the Test Data and Compute Evaluation Metrics

# %%
pred_train= model1.predict(train_x)
pred= model1.predict(test_x)

# %%
print('Mean squared error for training data : ', np.sqrt(mean_squared_error(train_y,pred_train)))
print('Mean squared error for testing data : ', np.sqrt(mean_squared_error(test_y,pred)))
# Out:
# Mean squared error for training data :  2.4999572198855557
# Mean squared error for testing data :  3.1310356362561134

# %%
print("R2 score for training data : ",r2_score(train_y,pred_train))
print("R2 score for testing data : ",r2_score(test_y,pred))
# Out:
# R2 score for training data :  0.9997779448853589
# R2 score for testing data :  0.9997974491141796
